# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import pyautogui
import pyperclip
from selenium.webdriver.common.action_chains import ActionChains

# 크롬 드라이버 자동 업데이트
from webdriver_manager.chrome import ChromeDriverManager


# 브라우저 꺼짐 방지
chrome_options = Options()
chrome_options.add_experimental_option("detach", True)




# 불필요한 에러 메시지 없애기
chrome_options.add_experimental_option("excludeSwitches", ["enable-logging"])

service = Service(executable_path=ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)



# 웹페이지 해당 주소 이동
driver.implicitly_wait(5)
driver.maximize_window()


url = "https://www.tistory.com/auth/login"


# 웹페이지 해당 주소 이동
driver.implicitly_wait(5)
driver.maximize_window()



driver.get(url)


time.sleep(3)

# %%
driver.find_element(By.CSS_SELECTOR, ".btn_login.link_tistory_id").click()
time.sleep(2)

driver.find_element(By.CSS_SELECTOR, "#loginId").send_keys("lsy588274@gmail.com")
driver.find_element(By.CSS_SELECTOR, "#loginPw").send_keys("thtk6738@@")

time.sleep(1)

driver.find_element(By.CSS_SELECTOR, ".btn_login").click()
time.sleep(1.5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\makingprogram\애드센스\블로그대행사_외주(1).ipynb 셀 2 line 1
#       <a href='vscode-notebook-cell:/c%3A/makingprogram/%EC%95%A0%EB%93%9C%EC%84%BC%EC%8A%A4/%EB%B8%94%EB%A1%9C%EA%B7%B8%EB%8C%80%ED%96%89%EC%82%AC_%EC%99%B8%EC%A3%BC%281%29.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a> time.sleep(1)
#       <a href='vscode-notebook-cell:/c%3A/makingprogram/%EC%95%A0%EB%93%9C%EC%84%BC%EC%8A%A4/%EB%B8%94%EB%A1%9C%EA%B7%B8%EB%8C%80%ED%96%89%EC%82%AC_%EC%99%B8%EC%A3%BC%281%29.ipynb#W1sZmlsZQ%3D%3D?line=8'>9</a> driver.find_element(By.CSS_SELECTOR, ".btn_g.highlight.submit").click()
# ---> <a href='vscode-notebook-cell:/c%3A/makingprogram/%EC%95%A0%EB%93%9C%EC%84%BC%EC%8A%A4/%EB%B8%94%EB%A1%9C%EA%B7%B8%EB%8C%80%ED%96%89%EC%82%AC_%EC%99%B8%EC%A3%BC%281%29.ipynb#W1sZmlsZQ%3D%3D?line=9'>10</a> time.sleep(1.5)
#
# KeyboardInterrupt:

# %%
driver.find_element(By.CSS_SELECTOR, ".link_profile").click()
time.sleep(0.5)

driver.find_element(By.CSS_SELECTOR, ".img_common_tistory.link_edit").click()
time.sleep(1)

try:
    result = driver.switch_to.alert
    result.dismiss()
except:
    pass

driver.switch_to.frame("editor-tistory_ifr")

# %%
with open(rf"C:\Users\user\Desktop\우회전차선직진.txt", 'r', encoding='utf-8') as file:
    contents = file.readlines()

for content in contents:
    driver.find_element(By.CSS_SELECTOR, "#tinymce").send_keys(content)

time.sleep(1)

driver.switch_to.default_content()

driver.find_element(By.CSS_SELECTOR, ".action").click()
time.sleep(1)

driver.quit()
